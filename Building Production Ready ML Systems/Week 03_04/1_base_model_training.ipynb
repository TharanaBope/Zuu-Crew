# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
                            confusion_matrix, 
                            f1_score,
                            accuracy_score,
                            precision_score,
                            recall_score
                            )
warnings.filterwarnings('ignore')

# %%
seed = 42
np.random.seed(seed)

# %% [markdown]
# ### Quick Overview of Logistic Regression
#
# Y_hat(Z) = 1 / (1 + exp(-Z))
#
# P(Y = 1 | X) = Y_hat(Z)

# %%
def sigmoid(Z):
    return 1 / (1 + np.exp(-Z))

X_linespace = np.linspace(-10, 10, 100)
Y_hat = sigmoid(X_linespace)

plt.plot(X_linespace, Y_hat)
plt.xlabel('Z')
plt.ylabel('Y_hat')
plt.show()

# %% [markdown]
# ### Loading the Data

# %%
X_train = np.load('artifacts/X_train.npz')['arr_0']
Y_train = np.load('artifacts/Y_train.npz')['arr_0']
X_test = np.load('artifacts/X_test.npz')['arr_0']
Y_test = np.load('artifacts/Y_test.npz')['arr_0']

# %% [markdown]
# ### Model Training

# %%
model_lr = LogisticRegression(
                            random_state = 42,
                            max_iter = 1000      
                            )
model_lr.fit(X_train, Y_train) # Fit the model
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %% [markdown]
# ### Inference

# %%
# Inference means making predictions on new data
# Predicting on train and test sets
Y_hat_train = model_lr.predict(X_train) # Predicting on train set
Y_hat_test = model_lr.predict(X_test) # Predicting on test set

# Predicting probabilities
Y_proba_train = model_lr.predict_proba(X_train) # Predicting probabilities on train set
Y_proba_test = model_lr.predict_proba(X_test) # Predicting probabilities on test set

# %%
Y_hat_train
# Out:
# array([0, 0, 0, ..., 1, 1, 0], shape=(12668,))

# %%
Y_proba_train
# Out:
# array([[0.83201964, 0.16798036],
#        [0.91486415, 0.08513585],
#        [0.74766146, 0.25233854],
#        ...,
#        [0.46479775, 0.53520225],
#        [0.36867483, 0.63132517],
#        [0.7050599 , 0.2949401 ]], shape=(12668, 2))
